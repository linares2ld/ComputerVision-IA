# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# Dataset: https://www.kaggle.com/alarcon7a/cnn-data-sources

# %%
im = io.imread('Data/cnn-data-sources/Mara.jpeg')

# %%
im.shape
# Out:
# (800, 600, 3)

# %%
plt.imshow(im)

# %%
r = im[:,:,0]
g = im[:,:,1]
b = im[:,:,2]

# %%
plt.imshow(r, cmap = 'gray')

# %%
n,m = r.shape
aux_dim = np.zeros([n,m])
im_r = np.dstack((r,aux_dim,aux_dim)).astype(np.uint8)
plt.imshow(im_r)
